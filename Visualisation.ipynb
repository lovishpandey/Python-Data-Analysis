# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn,randint,uniform,sample

# %%
pd.DataFrame(randn(1000))
# Out:
#             0
# 0    1.706159
# 1    0.155700
# 2    0.084878
# 3   -1.024964
# 4    0.161100
# ..        ...
# 995  0.695558
# 996  0.188144
# 997 -0.531204
# 998  1.599018
# 999 -0.753628
#
# [1000 rows x 1 columns]

# %%
ts = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts
# Out:
#                value
# 2019-06-07  0.259650
# 2019-06-08  0.501604
# 2019-06-09  0.228731
# 2019-06-10 -0.290069
# 2019-06-11 -1.072708
# ...              ...
# 2022-02-26 -1.085888
# 2022-02-27 -1.314751
# 2022-02-28 -0.508580
# 2022-03-01  0.114832
# 2022-03-02 -1.237327
#
# [1000 rows x 1 columns]

# %%
ts.plot(figsize=(10,10))

# %%
ts1=ts.cumsum()
ts1.plot(figsize=(10,10))

# %%
plt.plot(ts1)

# %%
df.plot()

# %%
iris =sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
x=iris.plot(figsize=(10,10), title ="Iris")
x.set_xlabel('X Axis')
x.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df=iris.drop('species', axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind="bar")

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['pclass'].plot(kind='bar')

# %%
df = pd.DataFrame(randn(10,4), columns=['a','b','c','d'])
df.head()
# Out:
#           a         b         c         d
# 0 -0.365549 -0.091608 -0.266920  0.865383
# 1 -0.602567 -0.095509 -0.241722  0.065104
# 2 -0.375318 -0.343513  1.453725 -1.887956
# 3 -0.021004  0.822796  0.685311  0.694845
# 4 -0.295064 -0.089745  0.771050 -1.090953

# %%
df.plot.bar()

# %%
df.plot.barh() ##rotated the axis of previous graph

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot.hist()

# %%
ts.plot(kind='bar')

# %%
df = iris.drop(['species'], axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot(kind='bar')## plotting categorical value

# %%
iris.plot(kind='hist', stacked= True, bins=50)

# %%
iris.plot(kind='hist', stacked= True, bins=50, orientation='horizontal')

# %%
iris['sepal_width'].diff().plot(kind='hist', stacked=True, bins=50)## difference between adjacent data

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic['fare'].plot()

# %%
titanic['survived'].plot(kind='hist')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.diff().hist(color='r',alpha=.1,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AED2A4F408>,
# ...
#       dtype=object)

# %%
df.plot.scatter(x='sepal_length', y='petal_length')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.plot.scatter(x='sepal_length', y='petal_length', c='sepal_width')

# %%
d=df.iloc[0]
d.plot.pie(figsize=(10,10))

# %%
d=df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(10,10))## subplot
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002AED2D2B108>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_`matrix

# %%
scatter_matrix(df,figsize=(10,10), diagonal='kde',color='b')
plt.show()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df['sepal_length'].plot.kde()# kernel density estimation for checking data is normalised or not

# %%
ts.plot(style='r', label='Series', legend=True )

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002AED466F508>,
# ...
#       dtype=object)

# %%
df.plot()

# %%
# !pip install plotly
# !pip install cufflinks
# !pip install foliu
# !pip install chart_studio
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement foliu (from versions: none)
# ERROR: No matching distribution found for foliu
# ...

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

# %%
import cufflinks as cf
from plotly.offline import iplot
